# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.2.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 39.7 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import random
import gensim.downloader as api

# Load a pre-trained word2vec model (you can also use other models like Glove)
model = api.load("word2vec-google-news-300")

def get_similar_words(seed_word, top_n=5):
    """Retrieve similar words for the given seed word."""
    try:
        similar_words = model.most_similar(seed_word, topn=top_n)
        return [word for word, _ in similar_words]
    except KeyError:
        return [seed_word]  # Return seed word if it's not in the vocabulary

def generate_paragraph(seed_word):
    """Generate a creative paragraph using similar words."""
    words = get_similar_words(seed_word)
    random.shuffle(words)

    paragraph = f"Once upon a time, there was a {seed_word} who dreamed of adventure. "
    for word in words:
        paragraph += f"One day, it stumbled upon a {word}, leading it into an unexpected journey. "
    paragraph += "The experience changed its life forever."
    return paragraph

# Example usage
seed_word = input("Enter a seed word: ")

words = get_similar_words(seed_word)
print("Similar Words Retrieved:", words)


print("\nGenerated Paragraph:\n")
print(generate_paragraph(seed_word))
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Enter a seed word: Ocean
# Similar Words Retrieved: ['Atlantic', 'Neptune', 'Sea_Isle', 'Surf', 'Cape']
#
# Generated Paragraph:
#
# Once upon a time, there was a Ocean who dreamed of adventure. One day, it stumbled upon a Surf, leading it into an unexpected journey. One day, it stumbled upon a Cape, leading it into an unexpected journey. One day, it stumbled upon a Sea_Isle, leading it into an unexpected journey. One day, it stumbled upon a Neptune, leading it into an unexpected journey. One day, it stumbled upon a Atlantic, leading it into an unexpected journey. The experience changed its life forever.
